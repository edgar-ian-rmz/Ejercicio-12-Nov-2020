# %% [markdown]
# <a href="https://colab.research.google.com/github/edgar-ian-rmz/Ejercicios-de-computadoras-y-programacion/blob/main/2_Dic_20cyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejemplo1
for i in[1,2,3,4,5]:
  print(f"el elemento: {i}")
# Out:
# el elemento: 1
# el elemento: 2
# el elemento: 3
# el elemento: 4
# el elemento: 5

# %%
#Ejemplo2

coleccion={"Mario":20, "Mariana":19, "Yessíca":14, "Luis":18}
for i in coleccion :
  print(f"El elemneto: {i}")
# Out:
# El elemneto: Mario
# El elemneto: Mariana
# El elemneto: Yessíca
# El elemneto: Luis

# %%
coleccion={"Mario":20, "Mariana":19, "Yessíca":14, "Luis":18}
for i in coleccion :
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
coleccion={"Mario":20, "Mariana":19, "Yessíca":14, "Luis":18}
for i in coleccion :
  print(f"{i} -> {coleccion [i]}")
# Out:
# Mario -> 20
# Mariana -> 19
# Yessíca -> 14
# Luis -> 18

# %%
coleccion={"Mario":20, "Mariana":19, "Yessíca":14, "Luis":18}

for clave, valor in coleccion.items():
  print(f"{clave} -> {valor}")
# Out:
# Mario -> 20
# Mariana -> 19
# Yessíca -> 14
# Luis -> 18

# %%
#Ejemplo3
email=False
for i in"ariel@unam.mx":
  if(i == "@"):
    email=True
if email== True:
  print("El correo es correcto")
  
else:
  print("el correo es incorrecto")
# Out:
# El correo es correcto

# %%
email=False
miEmail=input("Introduce tu correo electronico: ")
for i in miEmail:
  if(i == "@"):
    email=True
if email== True:
  print("El correo es correcto")
  
else:
  print("el correo es incorrecto")
# Out:
# Introduce tu correo electronico: edgar.unam.mx
# el correo es incorrecto

# %%
#Fot-Range

for i in range (5):
  print("Hola")
# Out:
# Hola
# Hola
# Hola
# Hola
# Hola

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (10):
  print(f"Valor de la valirable {i}")
# Out:
# Valor de la valirable 0
# Valor de la valirable 1
# Valor de la valirable 2
# Valor de la valirable 3
# Valor de la valirable 4
# Valor de la valirable 5
# Valor de la valirable 6
# Valor de la valirable 7
# Valor de la valirable 8
# Valor de la valirable 9

# %%
#While ejemplos

#Ejemplo1

i=1
while i<=10:
  print("Ejecuicon" + str (i))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# Ejecuicon1
# ...

# %%
i=1
while 1<=10:
  print("ejecucion" + str (i))

  i=i+1 #contador, es decir, incrementa en 1 la variable
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ejecucion16295
# ejecucion16296
# ejecucion16297
# ejecucion16298
# ejecucion16299
# ejecucion16300
# ejecucion16301
# ejecucion16302
# ejecucion16303
# ejecucion16304
# ejecucion16305
# ejecucion16306
# ejecucion16307
# ejecucion16308
# ejecucion16309
# ejecucion16310
# ejecucion16311
# ejecucion16312
# ejecucion16313
# ejecucion16314
# ejecucion16315
# ejecucion16316
# ejecucion16317
# ejecucion16318
# ejecucion16319
# ejecucion16320
# ejecucion16321
# ejecucion16322
# ejecucion16323
# ejecucion16324
# ejecucion16325
# ejecucion16326
# ejecucion16327
# ejecucion16328
# ejecucion16329
# ejecucion16330
# ejecucion16331
# ejecucion16332
# ejecucion16333
# ejecucion16334
# ejecucion16335
# ejecucion16336
# ejecucion16337
# ejecucion16338
# ejecucion16339
# ejecucion16340
# ejecucion16341
# ejecucion16342
# ejecucion16343
# ejecucion16344
# ejecucion16345
# ejecucion16346
# ejecucion16347
# ejecucion16348
# ejecucion16349
# ...

# %%
edad=int(input("Introduce tu edad: "))
while edad<0:
  print("has introducido una edad negativa, intentalo de nuevo")
  edad=int(input("Introduce tu edad: "))
print("gracias por participar. Puede pasar")
print("Edad del aspirante: " + str(edad))
# Out:
# Introduce tu edad: -34
# has introducido una edad negativa, intentalo de nuevo
# Introduce tu edad: 23
# gracias por participar. Puede pasar
# Edad del aspirante: 23

# %%
edad=int(input("Introduce tu edad: "))
while edad <10 or edad >100:
  print("has introducido una edad incorrecta, intentalo de nuevo")
  edad=int(input("Introduce tu edad: "))
print("gracias por participar. Puede pasar")
print("Edad del aspirante: " + str(edad))
# Out:
# Introduce tu edad: 120
# has introducido una edad incorrecta, intentalo de nuevo
# Introduce tu edad: -10
# has introducido una edad incorrecta, intentalo de nuevo
# Introduce tu edad: 18
# gracias por participar. Puede pasar
# Edad del aspirante: 18
